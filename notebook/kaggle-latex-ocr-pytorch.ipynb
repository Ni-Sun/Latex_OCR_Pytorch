# %%
# %%bash
# pip install editdistance
#
# # input是只读目录, 把项目放到working文件夹下
# if [ ! -d "/kaggle/working/latex-ocr-pytorch" ]; then
#     echo "目录不存在，正在复制..."
#     cp -r /kaggle/input/latex-ocr-pytorch /kaggle/working
# else
#     echo "目录已存在，跳过复制"
# fi

# %%
# %%bash
# cd /kaggle/working/latex-ocr-pytorch
# python train.py --data_name human_handwrite --use_huggingface
# # cd /kaggle/working/latex-ocr-pytorch && python train.py --data_name human_handwrite --use_huggingface

# %%
# %%bash
# cd /kaggle/working/latex-ocr-pytorch/
# if [ -d "checkpoints" ]; then
#     tar -czf checkpoints.tar.gz checkpoints
#     echo "压缩成功"
# else
#     echo "警告: checkpoints 目录不存在"
#     exit 1
# fi
