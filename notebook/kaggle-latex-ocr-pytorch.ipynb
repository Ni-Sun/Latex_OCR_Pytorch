# %%
# %%bash
# pip install editdistance
#
# cp -r /kaggle/input/latex-ocr-pytorch /kaggle/working
#
# mkdir -p /kaggle/working/latex-ocr-pytorch/checkpoints
# cp /kaggle/input/checkpoint*/* /kaggle/working/latex-ocr-pytorch/checkpoints/

# %%
# %%bash
# # 注意:
# # 1. 使用 --max_epochs 参数指定本次运行训练多少个epoch（防止训练时间过长）
# # 2. checkpoints会在每次保存后自动打包成checkpoints.tar.gz
# # 3. 训练日志会保存到training.log文件中（防止Kaggle日志无法显示）
#
# cd /kaggle/working/latex-ocr-pytorch
#
# # 首次训练：不指定checkpoint
# # python train.py --data_name human_handwrite --use_huggingface --max_epochs 10
#
# # 断点续训
# python train.py --data_name human_handwrite --use_huggingface --max_epochs 10 --checkpoint checkpoints/checkpoint_hf_human_handwrite_epoch13.pth.tar

# %%
# %%bash
# cd /kaggle/working/latex-ocr-pytorch/
# # Checkpoints已经自动打包，这个cell已经不需要了
# # 但如果需要手动打包，可以运行：
# # tar -czf checkpoints.tar.gz checkpoints
#
# # 查看checkpoint打包文件
# ls -lh checkpoints.tar.gz
